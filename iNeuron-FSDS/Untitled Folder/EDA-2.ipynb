# %% [markdown]
# ## EDA - 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv('cleaned_googleplaystore_data.csv')

# %%
df["Last Updated"] = pd.to_datetime(df["Last Updated"])

# %%
df["day"] = df["Last Updated"].dt.day

# %%
df["month"] = df["Last Updated"].dt.month

# %%
df["year"] = df["Last Updated"].dt.year

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0       4.0.3
# ...

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10835                               Sya9a Maroc - FR               FAMILY
# 10836               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                         Parkinson Exercices FR              MEDICAL
# 10838                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews     Size  Installs  Type  Price Content Rating  \
# 10835     4.5       38  53000.0      5000  Free    0.0       Everyone
# 10836     5.0        4   3600.0       100  Free    0.0       Everyone
# 10837     NaN        3   9500.0      1000  Free    0.0       Everyone
# 10838     4.5      114      NaN      1000  Free    0.0     Mature 17+
# 10839     4.5   398307  19000.0  10000000  Free    0.0       Everyone
#
#                   Genres Last Updated         Current Ver Android Ver  day  \
# ...

# %%
df.sample(10)
# Out:
#                                             App             Category  Rating  \
# 10818                                 Fanfic-FR  BOOKS_AND_REFERENCE     3.3
# 7282             CG Creative Sets: 2D/3D Artist   NEWS_AND_MAGAZINES     4.3
# 2141                              Monica Toy TV               FAMILY     4.7
# 8023                                 CW Nuclear  BOOKS_AND_REFERENCE     3.3
# 8548                                DM Talk New        COMMUNICATION     NaN
# 2414                               LTC AS Legal              MEDICAL     4.0
# 437               Mr. Number-Block calls & spam        COMMUNICATION     4.2
# 4983               My baby firework (Remove ad)               FAMILY     4.1
# 177    eBoox new: Reader for fb2 epub zip books  BOOKS_AND_REFERENCE     4.9
# 8915              Du Chinese – Mandarin Lessons               FAMILY     4.8
#
#        Reviews     Size  Installs  Type  Price Content Rating  \
# ...

# %%
df.shape
# Out:
# (9659, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9659 entries, 0 to 10839
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9659 non-null   object
#  1   Category        9659 non-null   object
#  2   Rating          8196 non-null   float64
#  3   Reviews         9659 non-null   int64
#  4   Size            8432 non-null   float64
#  5   Installs        9659 non-null   int64
#  6   Type            9658 non-null   object
#  7   Price           9659 non-null   float64
#  8   Content Rating  9659 non-null   object
#  9   Genres          9659 non-null   object
#  10  Last Updated    9659 non-null   datetime64[ns]
#  11  Current Ver     9651 non-null   object
#  12  Android Ver     8667 non-null   object
#  13  day             9659 non-null   int64
#  14  month           9659 non-null   int64
#  15  year            9659 non-null   int64
# ...

# %%
df.describe()
# Out:
#             Rating       Reviews           Size      Installs        Price  \
# count  8196.000000  9.659000e+03    8432.000000  9.659000e+03  9659.000000
# mean      4.173243  2.165926e+05   20384.448648  7.777507e+06     1.099299
# std       0.536625  1.831320e+06   21835.148282  5.375828e+07    16.852152
# min       1.000000  0.000000e+00      10.000000  0.000000e+00     0.000000
# 25%       4.000000  2.500000e+01    4500.000000  1.000000e+03     0.000000
# 50%       4.300000  9.670000e+02   12000.000000  1.000000e+05     0.000000
# 75%       4.500000  2.940100e+04   28000.000000  1.000000e+06     0.000000
# max       5.000000  7.815831e+07  100000.000000  1.000000e+09   400.000000
#
#                day        month         year
# count  9659.000000  9659.000000  9659.000000
# mean     15.632985     6.364013  2017.345688
# std       9.431017     2.659610     1.137600
# min       1.000000     1.000000  2010.000000
# 25%       7.000000     5.000000  2017.000000
# ...

# %%
df.describe().T
# Out:
#            count          mean           std     min     25%       50%  \
# Rating    8196.0  4.173243e+00  5.366247e-01     1.0     4.0       4.3
# Reviews   9659.0  2.165926e+05  1.831320e+06     0.0    25.0     967.0
# Size      8432.0  2.038445e+04  2.183515e+04    10.0  4500.0   12000.0
# Installs  9659.0  7.777507e+06  5.375828e+07     0.0  1000.0  100000.0
# Price     9659.0  1.099299e+00  1.685215e+01     0.0     0.0       0.0
# day       9659.0  1.563298e+01  9.431017e+00     1.0     7.0      16.0
# month     9659.0  6.364013e+00  2.659610e+00     1.0     5.0       7.0
# year      9659.0  2.017346e+03  1.137600e+00  2010.0  2017.0    2018.0
#
#                 75%           max
# Rating          4.5  5.000000e+00
# Reviews     29401.0  7.815831e+07
# Size        28000.0  1.000000e+05
# Installs  1000000.0  1.000000e+09
# Price           0.0  4.000000e+02
# day            24.0  3.100000e+01
# month           8.0  1.200000e+01
# year         2018.0  2.018000e+03

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'day', 'month', 'year'],
#       dtype='object')

# %% [markdown]
# ### EDA
# 1. **Univariate** - only one column
# 2. **Bivariate** - two columns
# 3. **Multivariate** - more than two columns

# %%
#to check the duplicate rows
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10835    False
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# Length: 9659, dtype: bool

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver, day, month, year]
# Index: []

# %%
df[df.duplicated('App')]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver, day, month, year]
# Index: []

# %%
#to drop duplicated value
df = df.drop_duplicates(subset = 'App',keep = 'first')
#check duplicates based on App column
#keep = first, keep only the first occurrence and drop the other remaining

# %%
df.shape
# Out:
# (9659, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9659 entries, 0 to 10839
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9659 non-null   object
#  1   Category        9659 non-null   object
#  2   Rating          8196 non-null   float64
#  3   Reviews         9659 non-null   int64
#  4   Size            8432 non-null   float64
#  5   Installs        9659 non-null   int64
#  6   Type            9658 non-null   object
#  7   Price           9659 non-null   float64
#  8   Content Rating  9659 non-null   object
#  9   Genres          9659 non-null   object
#  10  Last Updated    9659 non-null   datetime64[ns]
#  11  Current Ver     9651 non-null   object
#  12  Android Ver     8667 non-null   object
#  13  day             9659 non-null   int64
#  14  month           9659 non-null   int64
#  15  year            9659 non-null   int64
# ...

# %%
# segregating the features based on the datatype

# %%
numeric_feature = [feature for feature in df.columns if df[feature].dtype != 'O']

# %%
numeric_feature
# Out:
# ['Rating',
#  'Reviews',
#  'Size',
#  'Installs',
#  'Price',
#  'Last Updated',
#  'day',
#  'month',
#  'year']

# %%
df[numeric_feature]
# Out:
#        Rating  Reviews     Size  Installs  Price Last Updated  day  month  \
# 0         4.1      159  19000.0     10000    0.0   2018-01-07    7      1
# 1         3.9      967  14000.0    500000    0.0   2018-01-15   15      1
# 2         4.7    87510   8700.0   5000000    0.0   2018-08-01    1      8
# 3         4.5   215644  25000.0  50000000    0.0   2018-06-08    8      6
# 4         4.3      967   2800.0    100000    0.0   2018-06-20   20      6
# ...       ...      ...      ...       ...    ...          ...  ...    ...
# 10835     4.5       38  53000.0      5000    0.0   2017-07-25   25      7
# 10836     5.0        4   3600.0       100    0.0   2018-07-06    6      7
# 10837     NaN        3   9500.0      1000    0.0   2017-01-20   20      1
# 10838     4.5      114      NaN      1000    0.0   2015-01-19   19      1
# 10839     4.5   398307  19000.0  10000000    0.0   2018-07-25   25      7
#
#        year
# 0      2018
# 1      2018
# 2      2018
# 3      2018
# ...

# %%
categorical_feature = [feature for feature in df.columns if df[feature].dtype == 'O']

# %%
categorical_feature
# Out:
# ['App',
#  'Category',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Current Ver',
#  'Android Ver']

# %%
df[categorical_feature]
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#value counts of the categorical feature
df['Type'].value_counts()
# Out:
# Free    10039
# Paid      800
# Name: Type, dtype: int64

# %%
#to get in percentage
df['Type'].value_counts(normalize=True)*100
# Out:
# Free    92.619245
# Paid     7.380755
# Name: Type, dtype: float64

# %%
#to find the value counts for all the categorical features
for col in categorical_feature:
    print(f"{col}:{df[col].value_counts(normalize=True)*100}")
    print("=================================================")
# Out:
# App:ROBLOX                                                0.083026
# CBS Sports App - Scores, News, Stats & Watch Live     0.073801
# ESPN                                                  0.064576
# Duolingo: Learn Languages Free                        0.064576
# Candy Crush Saga                                      0.064576
#                                                         ...
# Meet U - Get Friends for Snapchat, Kik & Instagram    0.009225
# U-Report                                              0.009225
# U of I Community Credit Union                         0.009225
# Waiting For U Launcher Theme                          0.009225
# iHoroscope - 2018 Daily Horoscope & Astrology         0.009225
# Name: App, Length: 9659, dtype: float64
# ...
# Category:FAMILY                 18.191882
# GAME                   10.553506
# TOOLS                   7.776753
# MEDICAL                 4.271218
# BUSINESS                4.243542
# PRODUCTIVITY            3.911439
# ...

# %%
sns.countplot(x = df['Type'])
# Out:
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %%
sns.countplot(x = df['Content Rating'])
plt.show()

# %%
#categorical columns 
plt.figure(figsize=(20,15))
plt.suptitle('Univariate Analysis of Categorical features',fontsize = 20,fontweight = 'bold', alpha = 0.8, y =1)
category = ['Type' , 'Content Rating']
for i in range(0,len(category)):
    plt.subplot(2,2,i+1)
    sns.countplot(x = df[category[i]],palette = 'Set2')
    plt.xlabel = (category[i])
    plt.xticks(rotation = 45)
    plt.tight_layout()

# %%
numeric_feature
# Out:
# ['Rating',
#  'Reviews',
#  'Size',
#  'Installs',
#  'Price',
#  'Last Updated',
#  'day',
#  'month',
#  'year']

# %%
sns.kdeplot(df['Price'])
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
sns.kdeplot(df['Reviews'])
# Out:
# <AxesSubplot:xlabel='Reviews', ylabel='Density'>

# %%
sns.kdeplot(df['Rating'])
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Density'>

# %%
#numerical feature columns 
plt.figure(figsize=(10,15))
plt.suptitle('Univariate Analysis of Numerical features',fontsize = 20,fontweight = 'bold', alpha = 0.8, y =1)

for i in range(0,len(numeric_feature)):
    plt.subplot(5,3,i+1)
    sns.kdeplot(x = df[numeric_feature[i]],shade=True,color= 'r')
    plt.xlabel = (numeric_feature[i])
    plt.tight_layout()

# %%
sns.distplot(x = df['Price'])
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.displot(x = df['Rating'])

# %%
sns.distplot(x = df['Rating'])
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.histplot(x = df['Size'],kde = True)
# Out:
# <AxesSubplot:xlabel='Size', ylabel='Count'>

# %%
sns.histplot(x = df['Rating'],bins = 50)
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Count'>

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0       4.0.3
# ...

# %%
#Univariate Analysis

#most populat category in app
df[['Category']].value_counts()
# Out:
# Category
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# LIBRARIES_AND_DEMO       85
# AUTO_AND_VEHICLES        85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# ...

# %%
df[['Category']].value_counts().plot.bar()
# Out:
# <AxesSubplot:xlabel='Category'>

# %%
df['Category'].value_counts().plot.pie(figsize = (10,10),autopct = '%1.1f%%') #figsize = (15,15)
# Out:
# <AxesSubplot:ylabel='Category'>

# %%
#we also can save the figure

# %%
#to get top 10 category
df_topcat = df['Category'].value_counts()[:10]
df_topcat
# Out:
# FAMILY             1972
# GAME               1144
# TOOLS               843
# MEDICAL             463
# BUSINESS            460
# PRODUCTIVITY        424
# PERSONALIZATION     392
# COMMUNICATION       387
# SPORTS              384
# LIFESTYLE           382
# Name: Category, dtype: int64

# %%
category = pd.DataFrame(df['Category'].value_counts())
category.rename(columns = {'Category':'Count'},inplace = True)

# %%
plt.figure(figsize=(15,6))
sns.barplot(x = df_topcat,y = 'Count', data = category[:10],palette = 'hls')
plt.title("Top 10 App Category")
plt.xticks(rotation = 90)
plt.show()

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0       4.0.3
# ...

# %%
#which category has largest number of installations - bivariate
df.groupby(['Category'])['Installs'].sum().sort_values(ascending = False)
# Out:
# Category
# GAME                   35086024415
# COMMUNICATION          32647276251
# PRODUCTIVITY           14176091369
# SOCIAL                 14069867902
# TOOLS                  11452771915
# FAMILY                 10258263505
# PHOTOGRAPHY            10088247655
# NEWS_AND_MAGAZINES      7496317760
# TRAVEL_AND_LOCAL        6868887146
# VIDEO_PLAYERS           6222002720
# SHOPPING                3247848785
# ENTERTAINMENT           2869160000
# PERSONALIZATION         2325494782
# BOOKS_AND_REFERENCE     1921469576
# SPORTS                  1751174498
# HEALTH_AND_FITNESS      1583072512
# BUSINESS                1001914865
# FINANCE                  876648734
# EDUCATION                871452000
# MAPS_AND_NAVIGATION      724281890
# LIFESTYLE                537643539
# WEATHER                  426100520
# FOOD_AND_DRINK           273898751
# DATING                   264310807
# HOUSE_AND_HOME           168712461
# ART_AND_DESIGN           124338100
# ...

# %%
# to convert the above to a dataframe - reset_index()
df.groupby(['Category'])['Installs'].sum().sort_values(ascending = False).reset_index()
# Out:
#                Category     Installs
# 0                  GAME  35086024415
# 1         COMMUNICATION  32647276251
# 2          PRODUCTIVITY  14176091369
# 3                SOCIAL  14069867902
# 4                 TOOLS  11452771915
# 5                FAMILY  10258263505
# 6           PHOTOGRAPHY  10088247655
# 7    NEWS_AND_MAGAZINES   7496317760
# 8      TRAVEL_AND_LOCAL   6868887146
# 9         VIDEO_PLAYERS   6222002720
# 10             SHOPPING   3247848785
# 11        ENTERTAINMENT   2869160000
# 12      PERSONALIZATION   2325494782
# 13  BOOKS_AND_REFERENCE   1921469576
# 14               SPORTS   1751174498
# 15   HEALTH_AND_FITNESS   1583072512
# 16             BUSINESS   1001914865
# 17              FINANCE    876648734
# 18            EDUCATION    871452000
# 19  MAPS_AND_NAVIGATION    724281890
# 20            LIFESTYLE    537643539
# 21              WEATHER    426100520
# 22       FOOD_AND_DRINK    273898751
# 23               DATING    264310807
# ...

# %%
df_ctg_installs = df.groupby(['Category'])['Installs'].sum().sort_values(ascending = False).reset_index()

# %%
top_installs = df_ctg_installs.head(10)

# %%
top_installs
# Out:
#              Category     Installs
# 0                GAME  35086024415
# 1       COMMUNICATION  32647276251
# 2        PRODUCTIVITY  14176091369
# 3              SOCIAL  14069867902
# 4               TOOLS  11452771915
# 5              FAMILY  10258263505
# 6         PHOTOGRAPHY  10088247655
# 7  NEWS_AND_MAGAZINES   7496317760
# 8    TRAVEL_AND_LOCAL   6868887146
# 9       VIDEO_PLAYERS   6222002720

# %%
sns.barplot(x = 'Installs', y = 'Category', data = top_installs)
# Out:
# <AxesSubplot:xlabel='Installs', ylabel='Category'>

# %%
plt.figure(figsize = (14,10))
sns.set_context("talk")
sns.set_style("darkgrid")

ax = sns.barplot(x = 'Installs', y = 'Category' , data = top_installs)
ax.set_xlabel = ("No. of install in Billions")
ax.set_ylabel = ("")
ax.set_title = ("Most popular Categories in Play Store")

# %% [markdown]
# **What are the top 5 most installed app in Each Popular category**

# %%
#top 5 apps of Game category
df[df['Category'] == 'GAME'][['App','Installs']].sort_values(by = 'Installs',ascending = False).head()
# Out:
#                  App    Installs
# 1750  Subway Surfers  1000000000
# 1654  Subway Surfers  1000000000
# 1700  Subway Surfers  1000000000
# 1917  Subway Surfers  1000000000
# 3896  Subway Surfers  1000000000

# %%
#for cat in top_installs:
 #   top_five = df[df['Category'] == cat ][['App','Installs']].sort_values(by = 'Installs',ascending = False).head()

# %%
dfa = df.groupby(['Category','App'])['Installs'].sum().reset_index()

# %%
dfa
# Out:
#             Category                                                App  \
# 0     ART_AND_DESIGN                           350 Diy Room Decor Ideas
# 1     ART_AND_DESIGN    3D Color Pixel by Number - Sandbox Art Coloring
# 2     ART_AND_DESIGN                            AJ Styles HD Wallpapers
# 3     ART_AND_DESIGN  AJ Styles Wallpaper 2018 - AJ Styles HD Wallpaper
# 4     ART_AND_DESIGN                              Ai illustrator viewer
# ...              ...                                                ...
# 9739         WEATHER                                      Yahoo Weather
# 9740         WEATHER  Yahoo! Weather for SH Forecast for understandi...
# 9741         WEATHER                                     Yandex.Weather
# 9742         WEATHER                         weather - weather forecast
# 9743         WEATHER                     wetter.com - Weather and Radar
#
#       Installs
# 0        10000
# 1       100000
# 2         5000
# 3         1000
# 4       100000
# ...

# %%
dfa = dfa.sort_values('Installs',ascending = False)

# %%
dfa
# Out:
#              Category                                           App  \
# 4852             GAME                                Subway Surfers
# 7507     PRODUCTIVITY                                  Google Drive
# 7999           SOCIAL                                     Instagram
# 7160      PHOTOGRAPHY                                 Google Photos
# 1065    COMMUNICATION                                      Hangouts
# ...               ...                                           ...
# 2230           FAMILY                     Command & Conquer: Rivals
# 6918  PERSONALIZATION  Popsicle Launcher for Android P 9.0 launcher
# 547          BUSINESS                                    CX Network
# 7674     PRODUCTIVITY                                 cronometra-br
# 53     ART_AND_DESIGN                        Test Application DT 02
#
#         Installs
# 4852  6000000000
# 7507  4000000000
# 7999  4000000000
# 7160  4000000000
# 1065  4000000000
# ...          ...
# 2230           0
# ...

# %%
dfa[dfa.Category == 'GAME'][:5]
# Out:
#      Category               App    Installs
# 4852     GAME    Subway Surfers  6000000000
# 4245     GAME  Candy Crush Saga  3000000000
# 4881     GAME      Temple Run 2  3000000000
# 4707     GAME               Pou  1500000000
# 4659     GAME    My Talking Tom  1000000000

# %%
dfa[dfa.Category == 'PRODUCTIVITY'][:5]
# Out:
#           Category              App    Installs
# 7507  PRODUCTIVITY     Google Drive  4000000000
# 7505  PRODUCTIVITY  Google Calendar  1500000000
# 7444  PRODUCTIVITY          Dropbox  1500000000
# 7552  PRODUCTIVITY   Microsoft Word  1500000000
# 7414  PRODUCTIVITY      Cloud Print   500000000

# %%
dfa[dfa.Category == 'FAMILY'][:5]
# Out:
#      Category                App    Installs
# 2698   FAMILY  Google Play Games  1000000000
# 2149   FAMILY   Candy Crush Saga   500000000
# 3005   FAMILY     My Talking Tom   500000000
# 3135   FAMILY                Pou   500000000
# 3183   FAMILY             ROBLOX   400000000

# %%
apps = ['GAME','COMMUNICATION','PRODUCTIVITY','SOCIAL']
sns.set_context('poster')
sns.set_style("darkgrid")

plt.figure(figsize = (40,30))

for i,app in enumerate(apps):
    df2 = dfa[dfa.Category == app]
    df3 = df2.head(5)
    plt.subplot(4,2,i+1)
    sns.barplot(data = df3 , x = 'Installs', y = 'App')
    plt.xlabel = ("Installation in Millions")
    plt.ylabel = ('')
    plt.title(app,size = 20)

plt.tight_layout()
plt.subplots_adjust(hspace = .3)
plt.show()

# %% [markdown]
# **How many apps are there on Google Play Store which has 5 ratings ??**

# %%
df[df['Rating'] == 5]
# Out:
#                                               App   Category  Rating  Reviews  \
# 329                  Hojiboy Tojiboyev Life Hacks     COMICS     5.0       15
# 612                 American Girls Mobile Numbers     DATING     5.0        5
# 615                                  Awake Dating     DATING     5.0        2
# 633                         Spine- The dating app     DATING     5.0        5
# 636    Girls Live Talk - Free Text and Video Chat     DATING     5.0        6
# ...                                           ...        ...     ...      ...
# 10720                           Mad Dash Fo' Cash       GAME     5.0       14
# 10741                       GKPB FP Online Church  LIFESTYLE     5.0       32
# 10775                            Monster Ride Pro       GAME     5.0        1
# 10819                             Fr. Daoud Lamei     FAMILY     5.0       22
# 10836            Fr. Mike Schmitz Audio Teachings     FAMILY     5.0        4
#
# ...

# %%
df[df['Rating'] == 5].shape[0]
# Out:
# 274

# %%
len(df[df['Rating'] == 5])
# Out:
# 274

# %%
df[df['Rating'] == 5][['App','Rating']]
# Out:
#                                               App  Rating
# 329                  Hojiboy Tojiboyev Life Hacks     5.0
# 612                 American Girls Mobile Numbers     5.0
# 615                                  Awake Dating     5.0
# 633                         Spine- The dating app     5.0
# 636    Girls Live Talk - Free Text and Video Chat     5.0
# ...                                           ...     ...
# 10720                           Mad Dash Fo' Cash     5.0
# 10741                       GKPB FP Online Church     5.0
# 10775                            Monster Ride Pro     5.0
# 10819                             Fr. Daoud Lamei     5.0
# 10836            Fr. Mike Schmitz Audio Teachings     5.0
#
# [274 rows x 2 columns]

# %%
rating = df.groupby(['App'])['Rating'].sum().sort_values(ascending = False).reset_index()

# %%
rating
# Out:
#                                                     App  Rating
# 0                                                ROBLOX    40.5
# 1     CBS Sports App - Scores, News, Stats & Watch Live    34.4
# 2                        Duolingo: Learn Languages Free    32.9
# 3                                           8 Ball Pool    31.5
# 4                                      Candy Crush Saga    30.8
# ...                                                 ...     ...
# 9654                                  BL 1-Click Camera     0.0
# 9655                                BK Travel Solutions     0.0
# 9656  Love Calendar - Couple Sharing Calendar & Coup...     0.0
# 9657                                              Luffs     0.0
# 9658               "i DT" Fútbol. Todos Somos Técnicos.     0.0
#
# [9659 rows x 2 columns]

# %%
rating[rating.Rating == 5]
# Out:
#                                                     App  Rating
# 788                                             BI News     5.0
# 789   FD Calculator (EMI, SIP, RD & Loan Eligilibility)     5.0
# 790                                    CJ's Coffee Cafe     5.0
# 791                                    CP Installer App     5.0
# 792                                        ADS-B Driver     5.0
# ...                                                 ...     ...
# 1052                                                 BV     5.0
# 1053               Food-Aw - Order Food Online in Aruba     5.0
# 1054                              Spine- The dating app     5.0
# 1055                    Speeding Joyride & Car Meet App     5.0
# 1056                              Nur təfsiri 1-ci cild     5.0
#
# [269 rows x 2 columns]

# %%
rating2 = rating = df.groupby(['Category','Installs','App'])['Rating'].sum().sort_values(ascending = False).reset_index()

# %%
rating2
# Out:
#             Category   Installs  \
# 0             SPORTS    5000000
# 1             SPORTS   10000000
# 2               GAME   50000000
# 3               GAME   10000000
# 4               GAME  100000000
# ...              ...        ...
# 9747    PRODUCTIVITY         10
# 9748    PRODUCTIVITY         10
# 9749    PRODUCTIVITY         10
# 9750    PRODUCTIVITY         10
# 9751  ART_AND_DESIGN          0
#
#                                                     App  Rating
# 0     CBS Sports App - Scores, News, Stats & Watch Live    34.4
# 1                                                  ESPN    29.4
# 2                                            Bowmasters    28.2
# 3                                       Zombie Catchers    28.2
# 4      Sniper 3D Gun Shooter: Free Shooting Games - FPS    27.6
# ...                                                 ...     ...
# 9747                                           BW Ultra     0.0
# ...

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'day', 'month', 'year'],
#       dtype='object')

# %%
plt.figure(figsize = (15,15))
sns.scatterplot(data = df , y = "Category", x = 'Price')
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Category'>

# %% [markdown]
# **Which category app users are reviewing the most ??**

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0       4.0.3
# ...

# %%
df.groupby('Category')['Reviews'].sum().sort_values(ascending = False)
# Out:
# Category
# GAME                   1585422349
# COMMUNICATION           815462260
# SOCIAL                  621241422
# FAMILY                  410226330
# TOOLS                   273185044
# PHOTOGRAPHY             213516650
# SHOPPING                115041222
# PRODUCTIVITY            114116975
# VIDEO_PLAYERS           110380188
# PERSONALIZATION          89346140
# SPORTS                   70830169
# TRAVEL_AND_LOCAL         62617919
# ENTERTAINMENT            59178154
# NEWS_AND_MAGAZINES       54400863
# EDUCATION                39595786
# HEALTH_AND_FITNESS       37893743
# MAPS_AND_NAVIGATION      30659254
# BOOKS_AND_REFERENCE      21959069
# FINANCE                  17550728
# WEATHER                  14604735
# BUSINESS                 13954552
# LIFESTYLE                12882784
# FOOD_AND_DRINK            8883330
# DATING                    7291278
# HOUSE_AND_HOME            3976385
# COMICS                    3383276
# ART_AND_DESIGN            1714440
# ...

# %%
top_reviews_ctg = df.groupby('Category')['Reviews'].sum().sort_values(ascending = False)[:5]

# %%
top_reviews_ctg
# Out:
# Category
# GAME             1585422349
# COMMUNICATION     815462260
# SOCIAL            621241422
# FAMILY            410226330
# TOOLS             273185044
# Name: Reviews, dtype: int64

# %%
df.groupby(['Category','App'])['Reviews'].sum().reset_index()
# Out:
#             Category                                                App  \
# 0     ART_AND_DESIGN                           350 Diy Room Decor Ideas
# 1     ART_AND_DESIGN    3D Color Pixel by Number - Sandbox Art Coloring
# 2     ART_AND_DESIGN                            AJ Styles HD Wallpapers
# 3     ART_AND_DESIGN  AJ Styles Wallpaper 2018 - AJ Styles HD Wallpaper
# 4     ART_AND_DESIGN                              Ai illustrator viewer
# ...              ...                                                ...
# 9739         WEATHER                                      Yahoo Weather
# 9740         WEATHER  Yahoo! Weather for SH Forecast for understandi...
# 9741         WEATHER                                     Yandex.Weather
# 9742         WEATHER                         weather - weather forecast
# 9743         WEATHER                     wetter.com - Weather and Radar
#
#       Reviews
# 0          27
# 1        1518
# 2          48
# 3          18
# 4         486
# ...

# %%
#using agg()
df.groupby('Category').agg({"Installs":"sum",'Reviews':"sum"}).reset_index()
# Out:
#                Category     Installs     Reviews
# 0        ART_AND_DESIGN    124338100     1714440
# 1     AUTO_AND_VEHICLES     53130211     1163666
# 2                BEAUTY     27197050      396240
# 3   BOOKS_AND_REFERENCE   1921469576    21959069
# 4              BUSINESS   1001914865    13954552
# 5                COMICS     56086150     3383276
# 6         COMMUNICATION  32647276251   815462260
# 7                DATING    264310807     7291278
# 8             EDUCATION    871452000    39595786
# 9         ENTERTAINMENT   2869160000    59178154
# 10               EVENTS     15973161      161018
# 11               FAMILY  10258263505   410226330
# 12              FINANCE    876648734    17550728
# 13       FOOD_AND_DRINK    273898751     8883330
# 14                 GAME  35086024415  1585422349
# 15   HEALTH_AND_FITNESS   1583072512    37893743
# 16       HOUSE_AND_HOME    168712461     3976385
# 17   LIBRARIES_AND_DEMO     62995910     1037118
# ...

# %%
fig,ax = plt.subplots(1,2,figsize = (20,7))
df.value_counts('Type').plot.pie(y = 'Type',startangle = 90, explode = (0.2,0), title = "Percentage of the Fee App and Paid App",legend = False , autopct = '%.2f' , ax = ax[0] )
ax[0].set(ylabel = 'Type of Apps')
df.groupby('Type').agg({'Installs':sum}).plot.pie(y = 'Installs',startangle = 90 , explode = (0.2,0), title = "Percentage of installs for the Fee App and Paid App" ,legend = False , autopct = '%.2f' , ax = ax[1] )
# Out:
# <AxesSubplot:title={'center':'Percentage of installs for the Fee App and Paid App'}, ylabel='Installs'>

# %%
df.groupby('Type').agg({'Installs':sum})
# Out:
#           Installs
# Type
# Free  167560477406
# Paid      72956081

# %%
#box plot - 2 variables
sns.boxplot(x = "Installs",y = "Rating",data = df)
plt.xticks(size = 10,rotation = 90)
plt.show()

# %%
sns.boxplot(x = "Installs",y = "Price",data = df)
# Out:
# <AxesSubplot:xlabel='Installs', ylabel='Price'>

# %%
plt.figure(figsize=(20,15))
sns.boxplot(x = "Category",y = "Rating",data = df)
plt.xticks(size = 15,rotation = 90)
plt.show()

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0       4.0.3
# ...

# %% [markdown]
# **Which Category are of largest size**

# %%
df.groupby('Category')["Size"].sum().sort_values(ascending = False)
# Out:
# Category
# FAMILY                 51880867.0
# GAME                   45035650.0
# MEDICAL                 8509013.0
# SPORTS                  7549453.0
# TOOLS                   6481954.0
# HEALTH_AND_FITNESS      6011072.0
# BUSINESS                5778875.0
# FINANCE                 5504070.0
# LIFESTYLE               5080312.0
# TRAVEL_AND_LOCAL        4723673.0
# PHOTOGRAPHY             4401397.0
# PERSONALIZATION         4010843.0
# PRODUCTIVITY            3913389.0
# SOCIAL                  3713193.0
# DATING                  3514628.0
# SHOPPING                3251261.0
# COMMUNICATION           3118177.0
# NEWS_AND_MAGAZINES      2813108.0
# BOOKS_AND_REFERENCE     2622232.0
# EDUCATION               2307782.0
# FOOD_AND_DRINK          2218500.0
# VIDEO_PLAYERS           2107080.0
# ENTERTAINMENT           1966800.0
# MAPS_AND_NAVIGATION     1794389.0
# AUTO_AND_VEHICLES       1502786.0
# PARENTING               1215700.0
# HOUSE_AND_HOME          1086556.0
# ...

# %%
df.groupby('Category')["Size"].sum().sort_values(ascending = False)
# Out:
# Category
# FAMILY                 51880867.0
# GAME                   45035650.0
# MEDICAL                 8509013.0
# SPORTS                  7549453.0
# TOOLS                   6481954.0
# HEALTH_AND_FITNESS      6011072.0
# BUSINESS                5778875.0
# FINANCE                 5504070.0
# LIFESTYLE               5080312.0
# TRAVEL_AND_LOCAL        4723673.0
# PHOTOGRAPHY             4401397.0
# PERSONALIZATION         4010843.0
# PRODUCTIVITY            3913389.0
# SOCIAL                  3713193.0
# DATING                  3514628.0
# SHOPPING                3251261.0
# COMMUNICATION           3118177.0
# NEWS_AND_MAGAZINES      2813108.0
# BOOKS_AND_REFERENCE     2622232.0
# EDUCATION               2307782.0
# FOOD_AND_DRINK          2218500.0
# VIDEO_PLAYERS           2107080.0
# ENTERTAINMENT           1966800.0
# MAPS_AND_NAVIGATION     1794389.0
# AUTO_AND_VEHICLES       1502786.0
# PARENTING               1215700.0
# HOUSE_AND_HOME          1086556.0
# ...

# %%
plt.figure(figsize = (15,15))
sns.barplot('Category','Size',data = df)
plt.xticks(size = 15,rotation = 90)
plt.show()

# %%
#ploting the date variable
plt.subplots(figsize = (20,10))
freq = pd.Series()
freq = df['year'].value_counts()
freq.plot()
plt.xlabel("Dates")
plt.ylabel("Number of updates")
plt.title("Time Series plot of last updates")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12432\2867353533.py in <module>
#       4 freq = df['year'].value_counts()
#       5 freq.plot()
# ----> 6 plt.xlabel("Dates")
#       7 plt.ylabel("Number of updates")
#       8 plt.title("Time Series plot of last updates")
#
# TypeError: 'str' object is not callable

# %%
plt.figure(figsize= (15,8))
sns.countplot(x = "Rating",data = df , palette = "Set1_r")
plt.xticks(rotation = 90)
plt.title("Countplot for ratings")
plt.show()
