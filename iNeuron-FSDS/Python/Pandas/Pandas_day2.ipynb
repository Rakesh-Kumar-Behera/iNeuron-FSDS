# %% [markdown]
# ## Pandas Day-2

# %%
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# '/home/jovyan/work/Pandas'

# %%
pd.read_csv("/home/jovyan/work/Pandas/Data/addresses.csv")
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
data = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.tail(4)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data.dtypes #returns datatype of each and every column
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data.info() #table summary - brief info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.describe() #statistical analalysis of the dataset
#it only displays numeric data summary
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#filter those column whose datatype is object
data[['Name' , 'Sex' , 'Ticket']].describe()
# Out:
#                            Name   Sex  Ticket
# count                       891   891     891
# unique                      891     2     681
# top     Braund, Mr. Owen Harris  male  347082
# freq                          1   577       7

# %%
type(data.dtypes)
# Out:
# pandas.core.series.Series

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data['Fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
data.dtypes == "object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
data.dtypes[data.dtypes == "object"]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
data.dtypes[data.dtypes == "object"].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
data[data.dtypes[data.dtypes == "object"].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
data[data.dtypes[data.dtypes == "object"].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#dataset where survived = 0
data[data['Survived']== 0]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
data[(data['Survived'] == 0) & (data['Sex'] == 'male')]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 881          882         0       3              Markun, Mr. Johann  male
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
data[(data['Survived'] == 0) & (data['Sex'] == 'male')].count()
# Out:
# PassengerId    468
# Survived       468
# Pclass         468
# Name           468
# Sex            468
# Age            360
# SibSp          468
# Parch          468
# Ticket         468
# Fare           468
# Cabin           62
# Embarked       468
# dtype: int64

# %%
#no of male passenger died
len(data[(data['Survived'] == 0) & (data['Sex'] == 'male')])
# Out:
# 468

# %%
#no of male passenger died
len(data[(data['Survived'] == 0) & (data['Sex'] == 'female')])
# Out:
# 81

# %%
data['Sex'].count()
# Out:
# 891

# %%
data['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
data[data['Sex']== 'male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
#no.of male onboarded
len(data[data['Sex']== 'male'])
# Out:
# 577

# %%
#no of female onboarded
len(data[data['Sex']== 'female'])
# Out:
# 314

# %%
#number of male survived
len(data[(data['Survived'] == 1) & (data['Sex'] == 'male')])
# Out:
# 109

# %%
#number of female survived
len(data[(data['Survived'] == 1) & (data['Sex'] == 'female')])
# Out:
# 233

# %%
#who paid highest fare
data['Fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
data[data['Fare'] == max(data['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
#Names of the persons who paid highest fare
data[data['Fare'] == max(data['Fare'])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
#Names of the persons who paid highest fare as data frame
data[data['Fare'] == max(data['Fare'])][['Name']]
# Out:
#                                    Name
# 258                    Ward, Miss. Anna
# 679  Cardeza, Mr. Thomas Drake Martinez
# 737              Lesurer, Mr. Gustave J

# %%
data[data['Fare'] == max(data['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
#person who paid minimum fair and survived
data[data['Fare'] == min(data['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#filter peoplewho received a cabin
data['Cabin']
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
data['Cabin'].describe()
# Out:
# count         204
# unique        147
# top       B96 B98
# freq            4
# Name: Cabin, dtype: object

# %%
data['Cabin'] == 'NaN'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Cabin, Length: 891, dtype: bool

# %%
data[data['Cabin'].isnull() == False]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
len(data[data['Cabin'].isnull() == False])
# Out:
# 204

# %%
#adding a new colun to the dataset
#similar to adding element to dict
data['New_col'] = 'raka'

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked New_col
# 0      0         A/5 21171   7.2500   NaN        S    raka
# 1      0          PC 17599  71.2833   C85        C    raka
# 2      0  STON/O2. 3101282   7.9250   NaN        S    raka
# 3      0            113803  53.1000  C123        S    raka
# ...

# %%
#add a duplicate of an existing column
data['Name_new'] = data['Name']

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked New_col  \
# 0      0         A/5 21171   7.2500   NaN        S    raka
# 1      0          PC 17599  71.2833   C85        C    raka
# 2      0  STON/O2. 3101282   7.9250   NaN        S    raka
# 3      0            113803  53.1000  C123        S    raka
# ...

# %%
#new col where data = age + pclass
data['age_Pclass'] = data['Age'] + data['Pclass']

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked New_col  \
# 0      0         A/5 21171   7.2500   NaN        S    raka
# 1      0          PC 17599  71.2833   C85        C    raka
# 2      0  STON/O2. 3101282   7.9250   NaN        S    raka
# 3      0            113803  53.1000  C123        S    raka
# ...

# %%
#to delete a column
#using drop
data.drop('New_col',axis = 1) #axis 0 - row, axis = 1  --> column
#changes is not permanent --
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#to permanently delete the column from the dataset
# data = data.drop('New_col', axis=1 ,inplace = True)
data.drop('Name_new', axis=1 ,inplace = True)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#deleting rows
data.drop(0) # changes are not permanent
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#index 0 is still present in the dataset
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#To make changes permanent --
# data = data.drop(0)
# data.drop(index = 0, inplace = True)

# %%
data = data.drop(0)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#extracting rows
# using iloc and loc

# %% [markdown]
# We can extract rows from a data set using `iloc` and `loc`

# %%
#extracting row1
data.iloc(1) #iloc - indexed location

# %%
data.iloc[1]#2nd row -- based on 0 index
# Out:
# PassengerId                         3
# Survived                            1
# Pclass                              3
# Name           Heikkinen, Miss. Laina
# Sex                            female
# Age                              26.0
# SibSp                               0
# Parch                               0
# Ticket               STON/O2. 3101282
# Fare                            7.925
# Cabin                             NaN
# Embarked                            S
# Name_new       Heikkinen, Miss. Laina
# age_Pclass                       29.0
# Name: 2, dtype: object

# %%
data.iloc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
data.loc[1]
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Name: 1, dtype: object

# %%
# data.iloc[0] == data.loc[1]
# iloc - (go after internal indexing or default indexing)fetches record startng from index 0 , first record will have 0 index, 2nd record have index 1 and so on
# loc - (go after named indexing, whatever indexes has been provided in the dataset)1-> first record, 2 --> second record and so on

# %%
#Syntax - .loc[rows,columns_name]  , iloc[row-indexes, col_indexes]

# %%
data.loc[2:6]
# Out:
#    PassengerId  Survived  Pclass  \
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
# 5                              Moran, Mr. James    male   NaN      0      0
# 6                       McCarthy, Mr. Timothy J    male  54.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S
# 5            330877   8.4583   NaN        Q
# 6             17463  51.8625   E46        S

# %%
data.loc[101:106, ['Survived','Pclass']]
# Out:
#      Survived  Pclass
# 101         0       3
# 102         0       1
# 103         0       3
# 104         0       3
# 105         0       3
# 106         1       3

# %%
data.loc[3:4, ['Fare','Cabin' , 'Embarked']]
# Out:
#     Fare Cabin Embarked
# 3  53.10  C123        S
# 4   8.05   NaN        S

# %%
data.loc[[3,4], ['Fare','Cabin' , 'Embarked']]
# Out:
#     Fare Cabin Embarked
# 3  53.10  C123        S
# 4   8.05   NaN        S

# %%
data.iloc[3:4, ['Fare','Cabin' , 'Embarked']]#as it is index based it will throw error - it always takes internal indexes
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [10], line 1
# ----> 1 data.iloc[3:4, ['Fare','Cabin' , 'Embarked']]
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1563, in _iLocIndexer._getitem_tuple(self, tup)
#    1561 def _getitem_tuple(self, tup: tuple):
# -> 1563     tup = self._validate_tuple_indexer(tup)
#    1564     with suppress(IndexingError):
#    1565         return self._getitem_lowerdim(tup)
#
# ...

# %%
data.iloc[[3,4], [9,10,11]]
# Out:
#     Fare Cabin Embarked
# 3  53.10  C123        S
# 4   8.05   NaN        S

# %%
data.loc[3:6,['PassengerId','Pclass']]
# Out:
#    PassengerId  Pclass
# 3            4       1
# 4            5       3
# 5            6       3
# 6            7       1

# %%
data.iloc[3:6,[0,2]]
# Out:
#    PassengerId  Pclass
# 3            4       1
# 4            5       3
# 5            6       3

# %%
#for entire row
data.loc[:,['PassengerId','Pclass']]
# Out:
#      PassengerId  Pclass
# 0              1       3
# 1              2       1
# 2              3       3
# 3              4       1
# 4              5       3
# ..           ...     ...
# 886          887       2
# 887          888       1
# 888          889       3
# 889          890       1
# 890          891       3
#
# [891 rows x 2 columns]

# %%
data.iloc[ : ,[0,2]]
# Out:
#      PassengerId  Pclass
# 0              1       3
# 1              2       1
# 2              3       3
# 3              4       1
# 4              5       3
# ..           ...     ...
# 886          887       2
# 887          888       1
# 888          889       3
# 889          890       1
# 890          891       3
#
# [891 rows x 2 columns]

# %%
data.iloc[[3,5],[0,1,2]]
# Out:
#    PassengerId  Survived  Pclass
# 3            4         1       1
# 5            6         0       3

# %%
data.loc[[3,5], ['PassengerId','Survived','Pclass']]
# Out:
#    PassengerId  Survived  Pclass
# 3            4         1       1
# 5            6         0       3

# %%
#all records where age > 35
data[data['Age'] > 35.0]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 6              7         0       1
# 11            12         1       1
# 13            14         0       3
# 15            16         1       2
# ..           ...       ...     ...
# 865          866         1       2
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
len(data[data['Age'] > 35.0])
# Out:
# 217

# %%
#age > 35 & Pclass = 1
data[(data['Age'] > 35.0) & (data['Pclass'] == 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 6              7         0       1
# 11            12         1       1
# 30            31         0       1
# 35            36         0       1
# ..           ...       ...     ...
# 856          857         1       1
# 857          858         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 30                            Uruchurtu, Don. Manuel E    male  40.0      0
# 35                      Holverson, Mr. Alexander Oskar    male  42.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
data1 = data.iloc[:5, [2,3,4,5,9,10]]

# %%
data1
# Out:
#    Pclass                                               Name     Sex   Age  \
# 0       3                            Braund, Mr. Owen Harris    male  22.0
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2       3                             Heikkinen, Miss. Laina  female  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                           Allen, Mr. William Henry    male  35.0
#
#       Fare Cabin
# 0   7.2500   NaN
# 1  71.2833   C85
# 2   7.9250   NaN
# 3  53.1000  C123
# 4   8.0500   NaN

# %%
#resetindexes and setindex
data1.set_index('Name')
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                        Fare Cabin
# Name
# Braund, Mr. Owen Harris                              7.2500   NaN
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# Heikkinen, Miss. Laina                               7.9250   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123
# Allen, Mr. William Henry                             8.0500   NaN

# %%
data1
# Out:
#    Pclass                                               Name     Sex   Age  \
# 0       3                            Braund, Mr. Owen Harris    male  22.0
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2       3                             Heikkinen, Miss. Laina  female  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                           Allen, Mr. William Henry    male  35.0
#
#       Fare Cabin
# 0   7.2500   NaN
# 1  71.2833   C85
# 2   7.9250   NaN
# 3  53.1000  C123
# 4   8.0500   NaN

# %%
data1.set_index('Name',inplace = True)

# %%
data1
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                        Fare Cabin
# Name
# Braund, Mr. Owen Harris                              7.2500   NaN
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# Heikkinen, Miss. Laina                               7.9250   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123
# Allen, Mr. William Henry                             8.0500   NaN

# %%
#drop all the records where we have null values in a row
data1.dropna()
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
#
#                                                        Fare Cabin
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123

# %%
data1
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                        Fare Cabin
# Name
# Braund, Mr. Owen Harris                              7.2500   NaN
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# Heikkinen, Miss. Laina                               7.9250   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123
# Allen, Mr. William Henry                             8.0500   NaN

# %%
#check column wise
data1.dropna(axis = 1)
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                        Fare
# Name
# Braund, Mr. Owen Harris                              7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833
# Heikkinen, Miss. Laina                               7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000
# Allen, Mr. William Henry                             8.0500

# %%
# drop() - drop entire column/row
# dropna() - check for null values first then drop rows/columns

# %%
data1
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                        Fare Cabin
# Name
# Braund, Mr. Owen Harris                              7.2500   NaN
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# Heikkinen, Miss. Laina                               7.9250   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123
# Allen, Mr. William Henry                             8.0500   NaN

# %%
#threshhold value ---> thresh - min that no of valid data (not NaN) should be present in rows/columns
data1.dropna(axis = 1,thresh = 3)
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                        Fare
# Name
# Braund, Mr. Owen Harris                              7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833
# Heikkinen, Miss. Laina                               7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000
# Allen, Mr. William Henry                             8.0500

# %% [markdown]
# 'Cabin' column was dropped bcoz it did not have the number of non-Na(not NaN) values mentioned in the 'thresh' attribute

# %%
data1.dropna(axis = 0,thresh = 5)
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
#
#                                                        Fare Cabin
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123

# %%
#fillna() - fill the NaN values (Na values) with some number

# %%
data1.fillna('Raka')
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                        Fare Cabin
# Name
# Braund, Mr. Owen Harris                              7.2500  Raka
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# Heikkinen, Miss. Laina                               7.9250  Raka
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123
# Allen, Mr. William Henry                             8.0500  Raka

# %%
data1.fillna(data['Age'].mean())
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                        Fare      Cabin
# Name
# Braund, Mr. Owen Harris                              7.2500  29.699118
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833        C85
# Heikkinen, Miss. Laina                               7.9250  29.699118
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000       C123
# Allen, Mr. William Henry                             8.0500  29.699118

# %%
data1.groupby('Sex').mean()
# Out:
# /tmp/ipykernel_88/1296023498.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data1.groupby('Sex').mean()
#           Pclass   Age       Fare
# Sex
# female  1.666667  33.0  44.102767
# male    3.000000  28.5   7.650000

# %%
data1.groupby('Sex').mean()['Age']
# Out:
# /tmp/ipykernel_88/3811166048.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data1.groupby('Sex').mean()['Age']
# Sex
# female    33.0
# male      28.5
# Name: Age, dtype: float64

# %%
#how much revenue generated from male
#how much revenue generated from female
data1.groupby('Sex').sum()['Fare']
# Out:
# /tmp/ipykernel_88/3478484078.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data1.groupby('Sex').sum()['Fare']
# Sex
# female    132.3083
# male       15.3000
# Name: Fare, dtype: float64

# %%
data1
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                        Fare Cabin
# Name
# Braund, Mr. Owen Harris                              7.2500   NaN
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# Heikkinen, Miss. Laina                               7.9250   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123
# Allen, Mr. William Henry                             8.0500   NaN

# %%
data2 = data.iloc[1:5 , 0:5]

# %%
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
pd.concat([data1,data2]) # horizontal merging
# Out:
#                                                     Pclass     Sex   Age  \
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
# 1                                                        1  female   NaN
# 2                                                        3  female   NaN
# 3                                                        1  female   NaN
# 4                                                        3    male   NaN
#
#                                                        Fare Cabin  \
# Braund, Mr. Owen Harris                              7.2500   NaN
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# ...

# %%
pd.concat([data1,data2], axis = 1)
# Out:
#                                                     Pclass     Sex   Age  \
# Braund, Mr. Owen Harris                                3.0    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...     1.0  female  38.0
# Heikkinen, Miss. Laina                                 3.0  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           1.0  female  35.0
# Allen, Mr. William Henry                               3.0    male  35.0
# 1                                                      NaN     NaN   NaN
# 2                                                      NaN     NaN   NaN
# 3                                                      NaN     NaN   NaN
# 4                                                      NaN     NaN   NaN
#
#                                                        Fare Cabin  \
# Braund, Mr. Owen Harris                              7.2500   NaN
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# ...

# %%
data1
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                        Fare Cabin
# Name
# Braund, Mr. Owen Harris                              7.2500   NaN
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# Heikkinen, Miss. Laina                               7.9250   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123
# Allen, Mr. William Henry                             8.0500   NaN

# %%
# pclass/3
# using apply() --> u can perform operation on columns
data1['new'] = data1['Pclass']

# %%
data1
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                        Fare Cabin  new
# Name
# Braund, Mr. Owen Harris                              7.2500   NaN    3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85    1
# Heikkinen, Miss. Laina                               7.9250   NaN    3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123    1
# Allen, Mr. William Henry                             8.0500   NaN    3

# %%
data1['new'] = data1['Pclass'].apply(lambda x : x/3)

# %%
data1
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                        Fare Cabin       new
# Name
# Braund, Mr. Owen Harris                              7.2500   NaN  1.000000
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85  0.333333
# Heikkinen, Miss. Laina                               7.9250   NaN  1.000000
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123  0.333333
# Allen, Mr. William Henry                             8.0500   NaN  1.000000

# %%
#alternate method
def fun1(x):
    return x/3

# %%
data1['new'] = data1['Pclass'].apply(fun1)

# %%
data1
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                        Fare Cabin       new
# Name
# Braund, Mr. Owen Harris                              7.2500   NaN  1.000000
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85  0.333333
# Heikkinen, Miss. Laina                               7.9250   NaN  1.000000
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123  0.333333
# Allen, Mr. William Henry                             8.0500   NaN  1.000000

# %%
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
#create a new column and store the length of their name
data2['Name_len'] = data2['Name'].apply(len)

# %%
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Name_len
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female        51
# 2                             Heikkinen, Miss. Laina  female        22
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female        44
# 4                           Allen, Mr. William Henry    male        24

# %%
def test2(x):
    if x == 'female':
        return 1
    else:
        return 0

# %%
data2['Sex'] = data2['Sex'].apply(test2)

# %%
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1
# 2                             Heikkinen, Miss. Laina    1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1
# 4                           Allen, Mr. William Henry    0

# %%
0-100  - 'A'
101 - 199 - 'B"
200+ - 'C"
# Out:
#   Cell In [11], line 2
#     101 - 199 - 'B"
#                 ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
def test3(x):
    if x <= 100 :
        return "A"
    elif x >100 and x<200:
        return "B"
    else :
        return "C"

# %%
data['Fare_group'] = data['Fare'].apply(test3)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
